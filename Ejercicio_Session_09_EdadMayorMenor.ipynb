# %%
edad1 = 25 #teria que colocar comando de Input, mas não estou conseguindo. Já pedi ajuda no Slack
if edad1>=18:
    print("Maior de idade")
elif edad1 <18:
    print("Menor de idade")
# Out:
# Maior de idade
